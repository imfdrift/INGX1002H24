# %% [markdown]
# # Numerisk integrasjon med trapesmetoden
#
# ### Integrasjon oppsummert
# Som vi kjenner til fra matematiske fag, vil den *integrerte* av en funskjon $f(x)$ være en ny funksjon $I(x) = \int f(x) dx$. Et nokså intuitivt eksempel på bruk av integrasjon vil være beregne posisjonen til et objekt over tid med utgangspunkt i informasjon om objektets hastighet over tid, samt startposisjon.
#
# > #### Eksempel 1:
# > La oss si at vi triller en ball langs et flatt underlag, og kjenner til at ballens hastighet over tid kan skrives som
# > $$v(t) =\begin{cases} 0, & t<0 \\ 20\cdot e^{-\frac{t}{2}},& 0\leq t < 10 \\ 0,& t\geq10 \end{cases}$$
# > der $t=0$ er tidspunktet ballen starter å trille, og ballen slutter å trille etter $t=10$ sekund. For å finne finne ut hvor langt ballen trillet må vi integrere funksjonen $v(t)$ fra tidspunktet $t=0$ til $t=10$, som gir posisjonen $x(t)$ til ballen ved tidspunktet $t=10$. Dette formulerer vi matematisk som et ***bundet integral***:
# >$$x(10) = \int_0^{10} 20\cdot e^{-\frac{t}{2}} \ dt $$
# > En velkjent måte å visualisere denne regneoperasjonen er som å finne *arealet* $A$ under *kurven* $v(t)$:
# > <img src="ball_int1.png" style="width: 700px; margin-left: 15%" /><br>
# > Med bruk av integrasjonsregler (som vi ikke går nærmere innpå her) kan vi finne ut at arealet under kurven i figur $1$, og dermed ballens posisjon etter $10$ sekund er:
# > $$x(10) = \int_0^{10}20e^{-\frac{t}{2}}dt = 40 - 40 e^{-\frac{10}{2}} \approx 39.73\text{ m}$$

# %% [markdown]
# ### Numerisk beregning av areal
#
# I situasjoner der vi ikke kan regne ut funksjonen $f(x)$ sin integrerte med kalkulus, eller bare ønsker å verifisere svaret vi fikk med kalkulus, vil numerisk intergrasjon være aktuelt. Ettersom integrasjon er sammenlignbart med å finne arealet til en ofte komplisert geometrisk form, vil en logisk tilnærming være å "fylle opp" området vi vil finne arealet til med enkle geometriske figurer som vi kjenner arealet til.

# %%
from numerikk_demoer import NumIntDemo
import numpy as np
# %matplotlib ipympl

def f(t):
    return 20*np.exp(-t/2)

NumIntDemo(f, [0, 10])
# Out:
# HBox(children=(BoundedIntText(value=7, continuous_update=True, description='N', layout=Layout(width='30%'), ma…
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Skrot under her!

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.close(1); plt.figure(1)
p0 = 0
v0 = 20

p = [p0]
v = [v0]

h = 0.01
t = np.linspace(0, 10, int(10/h+1))
for i in range(int(10/h)):
    p.append(p[-1] + h*v[-1])
    v.append(v[-1] - h*v[-1]*0.5)

plt.plot(t,np.array(p))
plt.plot(t,20*np.exp(-t*0.5))
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close(2); plt.figure(2, figsize=(9, 5))


def v(t):
    a = 0
    b = 10

    y = np.where((a<t)*(t<b), 20*np.exp(-t/2), 0)
    return y


t = np.linspace(-1, 11, 501)

plt.plot(t, v(t), label=r"$v(t)$", linewidth=2)
plt.fill_between(t, v(t), color='C0', alpha=0.2)#, label=r"$S=\int_0^{10} v(t) dt$")
plt.xlim([t[0], t[-1]])
plt.xlabel(r"Tid $t$ (sekund)")
plt.ylabel(r"Hastighet $v$ (m/s)")
plt.legend()
plt.plot([t[0], t[-1]], [0, 0], 'k', linewidth=0.7)
ylim = plt.gca().get_ylim()
plt.plot([0, 0], [-10, 50], 'k--', linewidth=0.7)
plt.plot([10, 10], [-10, 50], 'k--', linewidth=0.7)
plt.gca().set_ylim(ylim)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close(3); plt.figure(3, figsize=(12, 5))


def v(t):
    a = 0
    b = 10
    y = np.where((a<t)*(t<b), 20*np.exp(-t/2), 0)
    return y

def x(t):
    a = 0
    b = 10
    y = np.where((a<t), 40-40*np.exp(-t/2), 0)
    return y

t = np.linspace(-1, 11, 501)
plt.subplot(1,5, (1,3))
plt.plot(t, v(t), label=r"$v(t)$", linewidth=2)
plt.fill_between(t, v(t), color='C0', alpha=0.2)#, label=r"$S=\int_0^{10} v(t) dt$")
plt.xlim([t[0], t[-1]])
plt.xlabel(r"Tid $t$ (sekund)")
plt.ylabel(r"Hastighet $v$ (m/s)")
plt.legend()
plt.plot([t[0], t[-1]], [0, 0], 'k', linewidth=0.7)
ylim = plt.gca().get_ylim()
plt.plot([0, 0], [-10, 50], 'k--', linewidth=0.7)
plt.plot([10, 10], [-10, 50], 'k--', linewidth=0.7)
plt.gca().set_ylim(ylim)

plt.subplot(1,5, (4,5))
plt.plot(t, x(t))
plt.xlim([t[0], t[-1]])
plt.xlabel(r"Tid $t$ (sekund)")
plt.ylabel(r"Meter")
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
plt.close(2); plt.figure(2, figsize=(9, 5))


def v(t):
    a = 0
    b = 10

    y = np.where((a<=t)*(t<b), 20*np.exp(-t/2), 0)
    return y


t = np.linspace(-1, 11, 501)


plt.plot(t, v(t), label=r"$v(t)$", linewidth=2)
#plt.fill_between(t, v(t), color='C0', alpha=0.2)#, label=r"$S=\int_0^{10} v(t) dt$")
plt.xlim([t[0], t[-1]])
plt.xlabel(r"Tid $t$ (sekund)")
plt.ylabel(r"Hastighet $v$ (m/s)")
plt.legend()
plt.plot([t[0], t[-1]], [0, 0], 'k', linewidth=0.7)
ylim = plt.gca().get_ylim()
plt.plot([0, 0], [-10, 50], 'k--', linewidth=0.7)
plt.plot([10, 10], [-10, 50], 'k--', linewidth=0.7)
plt.gca().set_ylim(ylim)
plt.tight_layout()

# Plot triangles
plt.fill_between([0, 5, 5, 0], [0, 0, v(5), v(5)], color='C1', alpha=0.2, label=r"$A_1 = 5\cdot v(5)$")
plt.fill_between([5, 10, 5], [0, v(10), v(5)], color='C3', alpha=0.2, label=r"$A_2 = 10\cdot v(0) \cdot \frac{1}{2}$")
plt.fill_between([0, 5, 0], [v(5), v(5), v(0)], color='C2', alpha=0.2, label=r"$A_3 = 5\cdot (v(0)-v(5)) \cdot \frac{1}{2}$")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
